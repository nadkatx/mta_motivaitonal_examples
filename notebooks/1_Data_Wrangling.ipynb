# %% [markdown]
# # Google Merchandise Store MTA Data Wrangling
#
# We need to convert the raw clickstream to something we can do sequential MTA on. Also some intresting fields are nested so this data is techinically semi-structured and it might be good to flatten.
#
# The final result of this notebook includes:
#
#  - a sequence fact table, which has both conversion and dead end sequences all assigned a sequence id
#  - a visitor id detail table, which has 1 visitor id and some intresting details about the visitor such as browser, os, isp provider, ip address geography etc.

# %%
import pandas as pd
import numpy as np
import json
import secrets

pd.options.display.max_columns = None

# %%
folder = '../datasets/' # the ../ represents moving one folder back from current directory 
df = pd.read_csv(folder + 'clickstream_raw.csv')

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1  Organic Search  [{'index': '4', 'value': 'North America'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search                                          []  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Safari", "browserVersion": "not a...  1259490915281096752
# 1  {"browser": "Safari", "browserVersion": "not a...  5983987899933814948
# 2  {"browser": "Chrome", "browserVersion": "not a...  0875141984250977091
# 3  {"browser": "Chrome", "browserVersion": "not a...   451521411412093630
# 4  {"browser": "Chrome", "browserVersion": "not a...  6723102816157399269
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Asia", "subContinent": "Eastern...
# 3  {"continent": "Europe", "subContinent": "Weste...
# 4  {"continent": "Europe", "subContinent": "Easte...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "2", "pageviews": "2",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "3", "pageviews": "3",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508165159            2
# 1  {"campaign": "(not set)", "source": "google", ...  1508177658            1
# 2  {"campaign": "(not set)", "source": "google", ...  1508223135            1
# 3  {"campaign": "(not set)", "source": "google", ...  1508160016            3
# 4  {"campaign": "(not set)", "source": "google", ...  1508180825            1
#
#    visitStartTime
# 0      1508165159
# 1      1508177658
# 2      1508223135
# 3      1508160016
# 4      1508180825

# %%
def flatten_json(df, column_names_list):
    """
    This function will take a df and a list of column names to flatten
    """
    for col in column_names_list:
        # Convert the JSON string to a dictionary
        df[col] = df[col].apply(lambda x: json.loads(x))
        json_dict = pd.json_normalize(df[col])

        # Create new columns for each key-value pairing in the dictionary
        prefix = col + '_'
        for key in json_dict.columns:
            new_col_name = prefix + key
            df[new_col_name] = json_dict[key]

        # Drop the original column that contained the JSON string
        df = df.drop(columns=[col])

    return df

# %%
df2 = flatten_json(df,['device','geoNetwork','totals'])
df2.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1  Organic Search  [{'index': '4', 'value': 'North America'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search                                          []  20171016
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  5983987899933814948  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  0875141984250977091  [{'hitNumber': '1', 'time': '0', 'hour': '23',...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  6723102816157399269  [{'hitNumber': '1', 'time': '0', 'hour': '12',...
#
#    socialEngagementType                                      trafficSource  \
# 0  Not Socially Engaged  {"campaign": "(not set)", "source": "google", ...
# 1  Not Socially Engaged  {"campaign": "(not set)", "source": "google", ...
# 2  Not Socially Engaged  {"campaign": "(not set)", "source": "google", ...
# 3  Not Socially Engaged  {"campaign": "(not set)", "source": "google", ...
# 4  Not Socially Engaged  {"campaign": "(not set)", "source": "google", ...
#
#       visitId  visitNumber  visitStartTime device_browser  \
# 0  1508165159            2      1508165159         Safari
# 1  1508177658            1      1508177658         Safari
# 2  1508223135            1      1508223135         Chrome
# 3  1508160016            3      1508160016         Chrome
# 4  1508180825            1      1508180825         Chrome
#
#            device_browserVersion             device_browserSize  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device_operatingSystem  device_operatingSystemVersion  device_isMobile  \
# 0                    iOS  not available in demo dataset             True
# 1                    iOS  not available in demo dataset             True
# 2                  Linux  not available in demo dataset            False
# 3                Windows  not available in demo dataset            False
# 4                Windows  not available in demo dataset            False
#
#      device_mobileDeviceBranding       device_mobileDeviceModel  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#       device_mobileInputSelector        device_mobileDeviceInfo  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device_mobileDeviceMarketingName            device_flashVersion  \
# 0    not available in demo dataset  not available in demo dataset
# 1    not available in demo dataset  not available in demo dataset
# 2    not available in demo dataset  not available in demo dataset
# 3    not available in demo dataset  not available in demo dataset
# 4    not available in demo dataset  not available in demo dataset
#
#                  device_language            device_screenColors  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device_screenResolution device_deviceCategory geoNetwork_continent  \
# 0  not available in demo dataset                mobile               Europe
# 1  not available in demo dataset                mobile             Americas
# 2  not available in demo dataset               desktop                 Asia
# 3  not available in demo dataset               desktop               Europe
# 4  not available in demo dataset               desktop               Europe
#
#   geoNetwork_subContinent geoNetwork_country              geoNetwork_region  \
# 0          Western Europe        Netherlands  not available in demo dataset
# 1        Northern America      United States  not available in demo dataset
# 2            Eastern Asia             Taiwan  not available in demo dataset
# 3          Western Europe            Belgium                       Brussels
# 4          Eastern Europe            Romania  not available in demo dataset
#
#                 geoNetwork_metro                geoNetwork_city  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3                      (not set)                        Ixelles
# 4  not available in demo dataset  not available in demo dataset
#
#                geoNetwork_cityId geoNetwork_networkDomain  \
# 0  not available in demo dataset                (not set)
# 1  not available in demo dataset                  bhn.net
# 2  not available in demo dataset              nthu.edu.tw
# 3  not available in demo dataset                (not set)
# 4  not available in demo dataset                rdsnet.ro
#
#              geoNetwork_latitude           geoNetwork_longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#       geoNetwork_networkLocation totals_visits totals_hits totals_pageviews  \
# 0  not available in demo dataset             1           2                2
# 1  not available in demo dataset             1           2                2
# 2  not available in demo dataset             1           2                2
# 3  not available in demo dataset             1           2                2
# 4  not available in demo dataset             1           3                3
#
#   totals_timeOnSite totals_sessionQualityDim totals_newVisits  \
# 0                32                        1              NaN
# 1                51                        1                1
# 2                31                        1                1
# 3               571                        1              NaN
# 4                24                        1                1
#
#   totals_transactions totals_transactionRevenue  \
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN
#
#   totals_totalTransactionRevenue totals_bounces
# 0                            NaN            NaN
# 1                            NaN            NaN
# 2                            NaN            NaN
# 3                            NaN            NaN
# 4                            NaN            NaN

# %%
df2.fillna(0,inplace=True)

df2['visitStart_datetime'] = pd.to_datetime(df2['visitStartTime'], unit='s')

df2['visitEnd_datetime'] = pd.to_datetime(pd.to_numeric(df2['visitStartTime'])+pd.to_numeric(df2['totals_timeOnSite']), unit='s')

# Add one second to Visit End Datetime if equal to Visit Start Datetime
df2.loc[df2['visitStart_datetime'] == df2['visitEnd_datetime'], 'visitEnd_datetime'] += np.timedelta64(1, 's')


## hardcode of relevant columns

cols_to_keep = ['channelGrouping','visitStart_datetime','visitEnd_datetime'
            ,'visitNumber','fullVisitorId','device_browser'
            ,'device_operatingSystem','device_isMobile','device_deviceCategory'
            ,'geoNetwork_continent','geoNetwork_subContinent','geoNetwork_country'
            ,'geoNetwork_metro','geoNetwork_networkDomain','totals_pageviews'
            ,'totals_timeOnSite', 'totals_newVisits','totals_transactions'
            ,'totals_bounces']

df3 = df2[cols_to_keep]

num_cols = ['visitNumber','totals_pageviews','totals_timeOnSite'
            ,'totals_newVisits','totals_transactions','totals_bounces']


def convert_columns_to_numeric(df, columns):
    """
    This function takes any list of column names and will convert those to numeric
    """
    
    df[columns] = df[columns].apply(pd.to_numeric, errors='coerce')
    return df

df3 = convert_columns_to_numeric(df3,num_cols)

df3.sort_values(by=['fullVisitorId','visitStart_datetime'],inplace=True)

df3.head()
# Out:
# C:\Users\TEMPLSD\AppData\Local\Temp\ipykernel_22388\3165799986.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].apply(pd.to_numeric, errors='coerce')
# C:\Users\TEMPLSD\AppData\Local\Temp\ipykernel_22388\3165799986.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by=['fullVisitorId','visitStart_datetime'],inplace=True)
#       channelGrouping visitStart_datetime   visitEnd_datetime  visitNumber  \
# 43681  Organic Search 2017-06-01 18:13:16 2017-06-01 18:16:47            1
# 1145   Organic Search 2017-02-03 21:35:41 2017-02-03 21:35:42            1
# 45907         Display 2017-09-17 01:24:48 2017-09-17 01:24:49            1
# 45939         Display 2017-09-17 02:01:20 2017-09-17 02:01:21            2
# 36781          Direct 2017-10-12 01:02:05 2017-10-12 01:03:43            1
#
#              fullVisitorId device_browser device_operatingSystem  \
# 43681  0000650183049109374         Chrome                Android
# 1145   0000750929315523353         Safari              Macintosh
# 45907   000094154452308463         Safari                    iOS
# 45939   000094154452308463         Safari                    iOS
# 36781   000106364568517340         Chrome                Windows
#
#        device_isMobile device_deviceCategory geoNetwork_continent  \
# 43681             True                mobile                 Asia
# 1145             False               desktop             Americas
# 45907             True                tablet             Americas
# 45939             True                tablet             Americas
# 36781            False               desktop             Americas
#
#       geoNetwork_subContinent geoNetwork_country  \
# 43681           Southern Asia              India
# 1145         Northern America      United States
# 45907        Northern America      United States
# 45939        Northern America      United States
# 36781           South America               Peru
#
#                     geoNetwork_metro geoNetwork_networkDomain  \
# 43681                      (not set)                (not set)
# 1145   not available in demo dataset         zoominternet.net
# 45907  not available in demo dataset              verizon.net
# 45939  not available in demo dataset              verizon.net
# 36781                      (not set)               uns.edu.pe
#
#        totals_pageviews  totals_timeOnSite  totals_newVisits  \
# 43681                10                211                 1
# 1145                  1                  0                 1
# 45907                 1                  0                 1
# 45939                 1                  0                 0
# 36781                 2                 98                 1
#
#        totals_transactions  totals_bounces
# 43681                    0               0
# 1145                     0               1
# 45907                    0               1
# 45939                    0               1
# 36781                    0               0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121782 entries, 43681 to 108146
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   channelGrouping           121782 non-null  object
#  1   visitStart_datetime       121782 non-null  datetime64[ns]
#  2   visitEnd_datetime         121782 non-null  datetime64[ns]
#  3   visitNumber               121782 non-null  int64
#  4   fullVisitorId             121782 non-null  object
#  5   device_browser            121782 non-null  object
#  6   device_operatingSystem    121782 non-null  object
#  7   device_isMobile           121782 non-null  bool
#  8   device_deviceCategory     121782 non-null  object
#  9   geoNetwork_continent      121782 non-null  object
#  10  geoNetwork_subContinent   121782 non-null  object
#  11  geoNetwork_country        121782 non-null  object
#  12  geoNetwork_metro          121782 non-null  object
#  13  geoNetwork_networkDomain  121782 non-null  object
#  14  totals_pageviews          121782 non-null  int64
#  15  totals_timeOnSite         121782 non-null  int64
#  16  totals_newVisits          121782 non-null  int64
#  17  totals_transactions       121782 non-null  int64
#  18  totals_bounces            121782 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int64(6), object(10)
# memory usage: 17.8+ MB

# %%
## An example of a single visitor that has four website visits 0 conversions
df3.loc[df3['fullVisitorId']=='451521411412093630',:].sort_values(by=['visitStart_datetime'])
# Out:
#       channelGrouping visitStart_datetime   visitEnd_datetime  visitNumber  \
# 16306          Direct 2017-10-12 18:27:02 2017-10-12 18:41:04            1
# 16161  Organic Search 2017-10-12 18:56:44 2017-10-12 19:15:14            2
# 3      Organic Search 2017-10-16 13:20:16 2017-10-16 13:29:47            3
# 164    Organic Search 2017-10-16 14:06:30 2017-10-16 14:06:31            4
#
#             fullVisitorId device_browser device_operatingSystem  \
# 16306  451521411412093630         Chrome                Windows
# 16161  451521411412093630         Chrome                Windows
# 3      451521411412093630         Chrome                Windows
# 164    451521411412093630         Chrome                Windows
#
#        device_isMobile device_deviceCategory geoNetwork_continent  \
# 16306            False               desktop               Europe
# 16161            False               desktop               Europe
# 3                False               desktop               Europe
# 164              False               desktop               Europe
#
#       geoNetwork_subContinent geoNetwork_country  \
# 16306          Western Europe            Belgium
# 16161          Western Europe            Belgium
# 3              Western Europe            Belgium
# 164            Western Europe            Belgium
#
#                     geoNetwork_metro geoNetwork_networkDomain  \
# 16306  not available in demo dataset                (not set)
# 16161  not available in demo dataset                (not set)
# 3                          (not set)                (not set)
# 164                        (not set)                (not set)
#
#        totals_pageviews  totals_timeOnSite  totals_newVisits  \
# 16306                 5                842                 1
# 16161                 3               1110                 0
# 3                     2                571                 0
# 164                   1                  0                 0
#
#        totals_transactions  totals_bounces
# 16306                    0               0
# 16161                    0               0
# 3                        0               0
# 164                      0               1

# %% [markdown]
# ## Assumptions to make visitor control variables table
#
# <b> 1 We will take the visitor characteristics from the very first visit just so we guarantee to get a 1 to 1 mapping of id to characteristics </b>

# %%
# This gives us a first row for every unique visitor id to filter on. 
# For some reason cannot rely on newvisits in rare cases a single visitor id can have more than one newvisit

df3['obs_count'] = df3.groupby('fullVisitorId').cumcount() + 1

detail_cols = df3.columns[5:13]


visitor_detail_df = df3.loc[df3['obs_count']==1, ['fullVisitorId'] + list(detail_cols)].reset_index(drop=True)
visitor_detail_df.head()
# Out:
# C:\Users\TEMPLSD\AppData\Local\Temp\ipykernel_22388\3380343767.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['obs_count'] = df3.groupby('fullVisitorId').cumcount() + 1
#          fullVisitorId device_browser device_operatingSystem  device_isMobile  \
# 0  0000650183049109374         Chrome                Android             True
# 1  0000750929315523353         Safari              Macintosh            False
# 2   000094154452308463         Safari                    iOS             True
# 3   000106364568517340         Chrome                Windows            False
# 4  0001348344294054462         Chrome                  Linux            False
#
#   device_deviceCategory geoNetwork_continent geoNetwork_subContinent  \
# 0                mobile                 Asia           Southern Asia
# 1               desktop             Americas        Northern America
# 2                tablet             Americas        Northern America
# 3               desktop             Americas           South America
# 4               desktop             Americas        Northern America
#
#   geoNetwork_country               geoNetwork_metro
# 0              India                      (not set)
# 1      United States  not available in demo dataset
# 2      United States  not available in demo dataset
# 3               Peru                      (not set)
# 4      United States                    New York NY

# %%
## this df has one visitor id and then some potential control variables we associate to that visitor id
visitor_detail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99613 entries, 0 to 99612
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fullVisitorId            99613 non-null  object
#  1   device_browser           99613 non-null  object
#  2   device_operatingSystem   99613 non-null  object
#  3   device_isMobile          99613 non-null  bool
#  4   device_deviceCategory    99613 non-null  object
#  5   geoNetwork_continent     99613 non-null  object
#  6   geoNetwork_subContinent  99613 non-null  object
#  7   geoNetwork_country       99613 non-null  object
#  8   geoNetwork_metro         99613 non-null  object
# dtypes: bool(1), object(8)
# memory usage: 6.2+ MB

# %%
visitor_detail_df['fullVisitorId'].nunique()
# Out:
# 99613

# %% [markdown]
# ## Assumptions to make sequencing data
#
# This is always a very tricky step of multi touch attribution. Think carefully about the business problem and what the "population" ought to be. Think *very* carefully about the negative cases or examples you want machine learning to consider.
#
# E.g. If you are doing a 90 day lookback window on conversions to formulate positive cases to model on how would you formulate the 90 day window on customer journies that result in no conversion? See #3 postive case and negative case rationale for the assumption for this motivating example.
#
# <b> 1 When a website visit contains a conversion, the vist end datetime is the conversion timestamp </b>
#
# <b> 2 When a website visit starts the channelgrouping and the visit start datetime form the touchpoint timestamp </b>
#
# <b> 3 Positve Case and Negative Case Rationale  </b>
#
# - positive cases: any time there is a conversion look back at all the channels that full visitor id used prior
# - negative cases: any time there is a visitor id with no conversions lets call the very last visit end datetime the psuedo negative conversion and pull all channels used prior
#
# <b> 4 If there were sequence activities before or after the dataset timeframe these were truncated </b>

# %% [markdown]
# #### grab positive sequences
#
# a single visitor id could have many vistis with a transaction, so a single visitor id could generate multiple customer journies to model on

# %%
conversion_df = df3.loc[df3['totals_transactions'] >= 1,['fullVisitorId','visitEnd_datetime']]
conversion_df['event_name'] = 'conversion'
conversion_df['event_datetime'] = conversion_df['visitEnd_datetime']
conversion_df['conversion_proximity'] = 0
conversion_df = conversion_df[['fullVisitorId','event_name','event_datetime','conversion_proximity']]
conversion_df.reset_index(drop=True,inplace=True)
conversion_df.head()
# Out:
#          fullVisitorId  event_name      event_datetime  conversion_proximity
# 0  0003961110741104601  conversion 2017-05-22 04:09:44                     0
# 1  0084383590795093998  conversion 2016-09-07 22:03:52                     0
# 2  0086819414174186743  conversion 2018-02-05 15:41:14                     0
# 3  0092577710025173656  conversion 2016-10-18 00:10:57                     0
# 4  0121011502564299055  conversion 2018-02-09 13:20:40                     0

# %% [markdown]
# #### conversion path ids
#
# We will need to keep track of conversion paths for modeling so we will generate our own unique conversion path ids

# %%
def generate_unique_ids(length):
    alphabet = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
    return ''.join(secrets.choice(alphabet) for _ in range(length))

customer_ids_1 = []
while len(customer_ids_1) < len(conversion_df):
    customer_ids_1.append(generate_unique_ids(15))
    
conversion_df['sequence_id'] = customer_ids_1
conversion_df.head()
# Out:
#          fullVisitorId  event_name      event_datetime  conversion_proximity  \
# 0  0003961110741104601  conversion 2017-05-22 04:09:44                     0
# 1  0084383590795093998  conversion 2016-09-07 22:03:52                     0
# 2  0086819414174186743  conversion 2018-02-05 15:41:14                     0
# 3  0092577710025173656  conversion 2016-10-18 00:10:57                     0
# 4  0121011502564299055  conversion 2018-02-09 13:20:40                     0
#
#        sequence_id
# 0  dU5UOwplcDCWn7Z
# 1  bXwLU1c6w7oGnm8
# 2  VLB22UcgcwWbqYi
# 3  pkzACIzTGu73XaJ
# 4  2kUVU2Hsi6R8UDO

# %%
conversion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fullVisitorId         1337 non-null   object
#  1   event_name            1337 non-null   object
#  2   event_datetime        1337 non-null   datetime64[ns]
#  3   conversion_proximity  1337 non-null   int64
#  4   sequence_id           1337 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 52.4+ KB

# %%
df3.head()
# Out:
#       channelGrouping visitStart_datetime   visitEnd_datetime  visitNumber  \
# 43681  Organic Search 2017-06-01 18:13:16 2017-06-01 18:16:47            1
# 1145   Organic Search 2017-02-03 21:35:41 2017-02-03 21:35:42            1
# 45907         Display 2017-09-17 01:24:48 2017-09-17 01:24:49            1
# 45939         Display 2017-09-17 02:01:20 2017-09-17 02:01:21            2
# 36781          Direct 2017-10-12 01:02:05 2017-10-12 01:03:43            1
#
#              fullVisitorId device_browser device_operatingSystem  \
# 43681  0000650183049109374         Chrome                Android
# 1145   0000750929315523353         Safari              Macintosh
# 45907   000094154452308463         Safari                    iOS
# 45939   000094154452308463         Safari                    iOS
# 36781   000106364568517340         Chrome                Windows
#
#        device_isMobile device_deviceCategory geoNetwork_continent  \
# 43681             True                mobile                 Asia
# 1145             False               desktop             Americas
# 45907             True                tablet             Americas
# 45939             True                tablet             Americas
# 36781            False               desktop             Americas
#
#       geoNetwork_subContinent geoNetwork_country  \
# 43681           Southern Asia              India
# 1145         Northern America      United States
# 45907        Northern America      United States
# 45939        Northern America      United States
# 36781           South America               Peru
#
#                     geoNetwork_metro geoNetwork_networkDomain  \
# 43681                      (not set)                (not set)
# 1145   not available in demo dataset         zoominternet.net
# 45907  not available in demo dataset              verizon.net
# 45939  not available in demo dataset              verizon.net
# 36781                      (not set)               uns.edu.pe
#
#        totals_pageviews  totals_timeOnSite  totals_newVisits  \
# 43681                10                211                 1
# 1145                  1                  0                 1
# 45907                 1                  0                 1
# 45939                 1                  0                 0
# 36781                 2                 98                 1
#
#        totals_transactions  totals_bounces  obs_count
# 43681                    0               0          1
# 1145                     0               1          1
# 45907                    0               1          1
# 45939                    0               1          2
# 36781                    0               0          1

# %%
## start with channel detail table, left join conversion details, calculate the istance in seconds between each visit channel start and 

df4 = df3.merge(conversion_df,how='left',on='fullVisitorId')
df4 = df4.dropna(subset=['event_name'])
df4['conversion_proximity'] = (df4['event_datetime'] - df4['visitStart_datetime']).dt.total_seconds()
df4 = df4.loc[df4['conversion_proximity']>=0,:]
df4 = df4[['fullVisitorId','channelGrouping','visitStart_datetime','conversion_proximity','sequence_id']]
df4.columns = ['fullVisitorId','event_name','event_datetime','conversion_proximity','sequence_id']
df4.head()
# Out:
#            fullVisitorId      event_name      event_datetime  \
# 15   0003961110741104601  Organic Search 2017-05-22 04:01:22
# 378  0084383590795093998        Referral 2016-09-07 21:58:00
# 387  0086819414174186743  Organic Search 2018-02-05 15:25:08
# 419  0092577710025173656  Organic Search 2016-10-17 20:57:11
# 420  0092577710025173656  Organic Search 2016-10-17 23:00:58
#
#      conversion_proximity      sequence_id
# 15                  502.0  dU5UOwplcDCWn7Z
# 378                 352.0  bXwLU1c6w7oGnm8
# 387                 966.0  VLB22UcgcwWbqYi
# 419               11626.0  pkzACIzTGu73XaJ
# 420                4199.0  pkzACIzTGu73XaJ

# %%
transactions_df = pd.concat([df4,conversion_df],ignore_index=True)
transactions_df.sort_values(by=['fullVisitorId','conversion_proximity'], ascending=[True,False], inplace=True)
transactions_df['event_name'] = transactions_df['event_name'].str.lower().str.replace(' ','_')
transactions_df.reset_index(drop=True,inplace=True)
transactions_df.head(15)
# Out:
#           fullVisitorId      event_name      event_datetime  \
# 0   0003961110741104601  organic_search 2017-05-22 04:01:22
# 1   0003961110741104601      conversion 2017-05-22 04:09:44
# 2   0084383590795093998        referral 2016-09-07 21:58:00
# 3   0084383590795093998      conversion 2016-09-07 22:03:52
# 4   0086819414174186743  organic_search 2018-02-05 15:25:08
# 5   0086819414174186743      conversion 2018-02-05 15:41:14
# 6   0092577710025173656  organic_search 2016-10-17 20:57:11
# 7   0092577710025173656  organic_search 2016-10-17 23:00:58
# 8   0092577710025173656      conversion 2016-10-18 00:10:57
# 9   0121011502564299055          direct 2017-11-08 17:00:09
# 10  0121011502564299055          direct 2017-11-08 17:00:09
# 11  0121011502564299055          direct 2017-12-22 16:01:29
# 12  0121011502564299055          direct 2017-12-22 22:19:32
# 13  0121011502564299055          direct 2017-12-23 16:17:07
# 14  0121011502564299055          direct 2017-12-22 16:01:29
#
#     conversion_proximity      sequence_id
# 0                  502.0  dU5UOwplcDCWn7Z
# 1                    0.0  dU5UOwplcDCWn7Z
# 2                  352.0  bXwLU1c6w7oGnm8
# 3                    0.0  bXwLU1c6w7oGnm8
# 4                  966.0  VLB22UcgcwWbqYi
# 5                    0.0  VLB22UcgcwWbqYi
# 6                11626.0  pkzACIzTGu73XaJ
# 7                 4199.0  pkzACIzTGu73XaJ
# 8                    0.0  pkzACIzTGu73XaJ
# 9              8629475.0  QNZPZitPL4zAB1t
# 10             8022031.0  2kUVU2Hsi6R8UDO
# 11             4831395.0  QNZPZitPL4zAB1t
# 12             4808712.0  QNZPZitPL4zAB1t
# 13             4744057.0  QNZPZitPL4zAB1t
# 14             4223951.0  2kUVU2Hsi6R8UDO

# %%
## here is an example of a visitorid with 6 conversions, note the first referral 01/10/2017 gets repeated 6 times
id_counts = transactions_df.loc[transactions_df['event_name']=='conversion']['fullVisitorId'].value_counts()
id_counts_2p = id_counts[id_counts >= 2].index.tolist()
transactions_df.loc[transactions_df['fullVisitorId']==id_counts_2p[0],:].sort_values(by=['event_datetime'])
# Out:
#            fullVisitorId  event_name      event_datetime  \
# 126  0608915197735218105    referral 2017-01-10 18:03:51
# 128  0608915197735218105    referral 2017-01-10 18:03:51
# 149  0608915197735218105    referral 2017-01-10 18:03:51
# 143  0608915197735218105    referral 2017-01-10 18:03:51
# 132  0608915197735218105    referral 2017-01-10 18:03:51
# 139  0608915197735218105    referral 2017-01-10 18:03:51
# 151  0608915197735218105  conversion 2017-01-10 18:14:38
# 146  0608915197735218105    referral 2017-01-13 22:26:32
# 141  0608915197735218105    referral 2017-01-13 22:26:32
# 133  0608915197735218105    referral 2017-01-13 22:26:32
# 127  0608915197735218105    referral 2017-01-13 22:26:32
# 131  0608915197735218105    referral 2017-01-13 22:26:32
# 152  0608915197735218105  conversion 2017-01-13 22:54:06
# 136  0608915197735218105    referral 2017-01-26 18:58:41
# 144  0608915197735218105    referral 2017-01-26 18:58:41
# 134  0608915197735218105    referral 2017-01-26 18:58:41
# 129  0608915197735218105    referral 2017-01-26 18:58:41
# 135  0608915197735218105    referral 2017-01-26 21:54:18
# 137  0608915197735218105    referral 2017-01-26 21:54:18
# 150  0608915197735218105    referral 2017-01-26 21:54:18
# 130  0608915197735218105    referral 2017-01-26 21:54:18
# 153  0608915197735218105  conversion 2017-01-26 22:04:57
# 145  0608915197735218105    referral 2017-03-13 19:26:29
# 142  0608915197735218105    referral 2017-03-13 19:26:29
# 138  0608915197735218105    referral 2017-03-13 19:26:29
# 154  0608915197735218105  conversion 2017-03-13 20:17:19
# 147  0608915197735218105    referral 2017-03-17 17:54:33
# 140  0608915197735218105    referral 2017-03-17 17:54:33
# 155  0608915197735218105  conversion 2017-03-17 18:08:41
# 148  0608915197735218105    referral 2017-03-31 19:11:15
# 156  0608915197735218105  conversion 2017-03-31 19:24:25
#
#      conversion_proximity      sequence_id
# 126             6916834.0  Y4oyYAHXnur2kSl
# 128             5702690.0  9EISjNWDQrTDLtz
# 149                 647.0  gvzdWs8NHkWhGqR
# 143              276615.0  OpI4gRy5JACBAdm
# 132             5364808.0  hDlvSlzb4DcKWYU
# 139             1396866.0  I7Rnwz88SG6wVRC
# 151                   0.0  gvzdWs8NHkWhGqR
# 146                1654.0  OpI4gRy5JACBAdm
# 141             1121905.0  I7Rnwz88SG6wVRC
# 133             5089847.0  hDlvSlzb4DcKWYU
# 127             6641873.0  Y4oyYAHXnur2kSl
# 131             5427729.0  9EISjNWDQrTDLtz
# 152                   0.0  OpI4gRy5JACBAdm
# 136             3979118.0  hDlvSlzb4DcKWYU
# 144               11176.0  I7Rnwz88SG6wVRC
# 134             4317000.0  9EISjNWDQrTDLtz
# 129             5531144.0  Y4oyYAHXnur2kSl
# 135             4306463.0  9EISjNWDQrTDLtz
# 137             3968581.0  hDlvSlzb4DcKWYU
# 150                 639.0  I7Rnwz88SG6wVRC
# 130             5520607.0  Y4oyYAHXnur2kSl
# 153                   0.0  I7Rnwz88SG6wVRC
# 145                3050.0  hDlvSlzb4DcKWYU
# 142              340932.0  9EISjNWDQrTDLtz
# 138             1555076.0  Y4oyYAHXnur2kSl
# 154                   0.0  hDlvSlzb4DcKWYU
# 147                 848.0  9EISjNWDQrTDLtz
# 140             1214992.0  Y4oyYAHXnur2kSl
# 155                   0.0  9EISjNWDQrTDLtz
# 148                 790.0  Y4oyYAHXnur2kSl
# 156                   0.0  Y4oyYAHXnur2kSl

# %%
## if you sort by converson path id fist you will better see the sequences that will be generated by the data to study

transactions_df.loc[transactions_df['fullVisitorId']==id_counts_2p[0],:].sort_values(by=['sequence_id','event_datetime'])
# Out:
#            fullVisitorId  event_name      event_datetime  \
# 128  0608915197735218105    referral 2017-01-10 18:03:51
# 131  0608915197735218105    referral 2017-01-13 22:26:32
# 134  0608915197735218105    referral 2017-01-26 18:58:41
# 135  0608915197735218105    referral 2017-01-26 21:54:18
# 142  0608915197735218105    referral 2017-03-13 19:26:29
# 147  0608915197735218105    referral 2017-03-17 17:54:33
# 155  0608915197735218105  conversion 2017-03-17 18:08:41
# 139  0608915197735218105    referral 2017-01-10 18:03:51
# 141  0608915197735218105    referral 2017-01-13 22:26:32
# 144  0608915197735218105    referral 2017-01-26 18:58:41
# 150  0608915197735218105    referral 2017-01-26 21:54:18
# 153  0608915197735218105  conversion 2017-01-26 22:04:57
# 143  0608915197735218105    referral 2017-01-10 18:03:51
# 146  0608915197735218105    referral 2017-01-13 22:26:32
# 152  0608915197735218105  conversion 2017-01-13 22:54:06
# 126  0608915197735218105    referral 2017-01-10 18:03:51
# 127  0608915197735218105    referral 2017-01-13 22:26:32
# 129  0608915197735218105    referral 2017-01-26 18:58:41
# 130  0608915197735218105    referral 2017-01-26 21:54:18
# 138  0608915197735218105    referral 2017-03-13 19:26:29
# 140  0608915197735218105    referral 2017-03-17 17:54:33
# 148  0608915197735218105    referral 2017-03-31 19:11:15
# 156  0608915197735218105  conversion 2017-03-31 19:24:25
# 149  0608915197735218105    referral 2017-01-10 18:03:51
# 151  0608915197735218105  conversion 2017-01-10 18:14:38
# 132  0608915197735218105    referral 2017-01-10 18:03:51
# 133  0608915197735218105    referral 2017-01-13 22:26:32
# 136  0608915197735218105    referral 2017-01-26 18:58:41
# 137  0608915197735218105    referral 2017-01-26 21:54:18
# 145  0608915197735218105    referral 2017-03-13 19:26:29
# 154  0608915197735218105  conversion 2017-03-13 20:17:19
#
#      conversion_proximity      sequence_id
# 128             5702690.0  9EISjNWDQrTDLtz
# 131             5427729.0  9EISjNWDQrTDLtz
# 134             4317000.0  9EISjNWDQrTDLtz
# 135             4306463.0  9EISjNWDQrTDLtz
# 142              340932.0  9EISjNWDQrTDLtz
# 147                 848.0  9EISjNWDQrTDLtz
# 155                   0.0  9EISjNWDQrTDLtz
# 139             1396866.0  I7Rnwz88SG6wVRC
# 141             1121905.0  I7Rnwz88SG6wVRC
# 144               11176.0  I7Rnwz88SG6wVRC
# 150                 639.0  I7Rnwz88SG6wVRC
# 153                   0.0  I7Rnwz88SG6wVRC
# 143              276615.0  OpI4gRy5JACBAdm
# 146                1654.0  OpI4gRy5JACBAdm
# 152                   0.0  OpI4gRy5JACBAdm
# 126             6916834.0  Y4oyYAHXnur2kSl
# 127             6641873.0  Y4oyYAHXnur2kSl
# 129             5531144.0  Y4oyYAHXnur2kSl
# 130             5520607.0  Y4oyYAHXnur2kSl
# 138             1555076.0  Y4oyYAHXnur2kSl
# 140             1214992.0  Y4oyYAHXnur2kSl
# 148                 790.0  Y4oyYAHXnur2kSl
# 156                   0.0  Y4oyYAHXnur2kSl
# 149                 647.0  gvzdWs8NHkWhGqR
# 151                   0.0  gvzdWs8NHkWhGqR
# 132             5364808.0  hDlvSlzb4DcKWYU
# 133             5089847.0  hDlvSlzb4DcKWYU
# 136             3979118.0  hDlvSlzb4DcKWYU
# 137             3968581.0  hDlvSlzb4DcKWYU
# 145                3050.0  hDlvSlzb4DcKWYU
# 154                   0.0  hDlvSlzb4DcKWYU

# %% [markdown]
# #### grab negative sequences
#
# We will grab all visitor ids with 0 transactions.
#
# We will query their very last visit end datetime as a dead end event.
#
# Then just like the conversion sequences we will assign a dead end a sequence id

# %%
df3.head()
# Out:
#       channelGrouping visitStart_datetime   visitEnd_datetime  visitNumber  \
# 43681  Organic Search 2017-06-01 18:13:16 2017-06-01 18:16:47            1
# 1145   Organic Search 2017-02-03 21:35:41 2017-02-03 21:35:42            1
# 45907         Display 2017-09-17 01:24:48 2017-09-17 01:24:49            1
# 45939         Display 2017-09-17 02:01:20 2017-09-17 02:01:21            2
# 36781          Direct 2017-10-12 01:02:05 2017-10-12 01:03:43            1
#
#              fullVisitorId device_browser device_operatingSystem  \
# 43681  0000650183049109374         Chrome                Android
# 1145   0000750929315523353         Safari              Macintosh
# 45907   000094154452308463         Safari                    iOS
# 45939   000094154452308463         Safari                    iOS
# 36781   000106364568517340         Chrome                Windows
#
#        device_isMobile device_deviceCategory geoNetwork_continent  \
# 43681             True                mobile                 Asia
# 1145             False               desktop             Americas
# 45907             True                tablet             Americas
# 45939             True                tablet             Americas
# 36781            False               desktop             Americas
#
#       geoNetwork_subContinent geoNetwork_country  \
# 43681           Southern Asia              India
# 1145         Northern America      United States
# 45907        Northern America      United States
# 45939        Northern America      United States
# 36781           South America               Peru
#
#                     geoNetwork_metro geoNetwork_networkDomain  \
# 43681                      (not set)                (not set)
# 1145   not available in demo dataset         zoominternet.net
# 45907  not available in demo dataset              verizon.net
# 45939  not available in demo dataset              verizon.net
# 36781                      (not set)               uns.edu.pe
#
#        totals_pageviews  totals_timeOnSite  totals_newVisits  \
# 43681                10                211                 1
# 1145                  1                  0                 1
# 45907                 1                  0                 1
# 45939                 1                  0                 0
# 36781                 2                 98                 1
#
#        totals_transactions  totals_bounces  obs_count
# 43681                    0               0          1
# 1145                     0               1          1
# 45907                    0               1          1
# 45939                    0               1          2
# 36781                    0               0          1

# %%
dead_ends_df = df3.groupby(['fullVisitorId'],as_index=False).agg(
    total_transactions = ('totals_transactions',np.sum)
    ,max_visitend = ('visitEnd_datetime',np.max)
)
dead_ends_df = dead_ends_df.loc[dead_ends_df['total_transactions']==0,:]
dead_ends_df['event_name'] = 'dead_end'
dead_ends_df['conversion_proximity'] = 0

dead_ends_df = dead_ends_df[['fullVisitorId','event_name','max_visitend','conversion_proximity']]
dead_ends_df.columns = ['fullVisitorId','event_name','event_datetime', 'conversion_proximity']

customer_ids_2 = []
while len(customer_ids_2) < len(dead_ends_df):
    customer_ids_2.append(generate_unique_ids(15))
    
dead_ends_df['sequence_id'] = customer_ids_2
dead_ends_df.head()
# Out:
#          fullVisitorId event_name      event_datetime  conversion_proximity  \
# 0  0000650183049109374   dead_end 2017-06-01 18:16:47                     0
# 1  0000750929315523353   dead_end 2017-02-03 21:35:42                     0
# 2   000094154452308463   dead_end 2017-09-17 02:01:21                     0
# 3   000106364568517340   dead_end 2017-10-12 01:03:43                     0
# 4  0001348344294054462   dead_end 2017-06-05 15:06:25                     0
#
#        sequence_id
# 0  nW31ahtlgEpFWi1
# 1  f6X79WOxA3jUxPU
# 2  L5wAoLtd1C6Cvvc
# 3  maGY5aACPGJoF9o
# 4  VCl4OtCpaCafWUv

# %%
df5 = df3.merge(dead_ends_df,how='left',on='fullVisitorId')
df5 = df5.dropna(subset=['event_name'])
df5['conversion_proximity'] = (df5['event_datetime'] - df5['visitStart_datetime']).dt.total_seconds()
df5 = df5.loc[df5['conversion_proximity']>=0,:]
df5 = df5[['fullVisitorId','channelGrouping','visitStart_datetime','conversion_proximity','sequence_id']]
df5.columns = ['fullVisitorId','event_name','event_datetime','conversion_proximity','sequence_id']
df5.head()
# Out:
#          fullVisitorId      event_name      event_datetime  \
# 0  0000650183049109374  Organic Search 2017-06-01 18:13:16
# 1  0000750929315523353  Organic Search 2017-02-03 21:35:41
# 2   000094154452308463         Display 2017-09-17 01:24:48
# 3   000094154452308463         Display 2017-09-17 02:01:20
# 4   000106364568517340          Direct 2017-10-12 01:02:05
#
#    conversion_proximity      sequence_id
# 0                 211.0  nW31ahtlgEpFWi1
# 1                   1.0  f6X79WOxA3jUxPU
# 2                2193.0  L5wAoLtd1C6Cvvc
# 3                   1.0  L5wAoLtd1C6Cvvc
# 4                  98.0  maGY5aACPGJoF9o

# %%
transactions_df2 = pd.concat([df5,dead_ends_df],ignore_index=True)
transactions_df2.sort_values(by=['fullVisitorId','conversion_proximity'], ascending=[True,False], inplace=True)
transactions_df2['event_name'] = transactions_df2['event_name'].str.lower().str.replace(' ','_')
transactions_df2.reset_index(drop=True,inplace=True)
transactions_df2.head(15)
# Out:
#           fullVisitorId      event_name      event_datetime  \
# 0   0000650183049109374  organic_search 2017-06-01 18:13:16
# 1   0000650183049109374        dead_end 2017-06-01 18:16:47
# 2   0000750929315523353  organic_search 2017-02-03 21:35:41
# 3   0000750929315523353        dead_end 2017-02-03 21:35:42
# 4    000094154452308463         display 2017-09-17 01:24:48
# 5    000094154452308463         display 2017-09-17 02:01:20
# 6    000094154452308463        dead_end 2017-09-17 02:01:21
# 7    000106364568517340          direct 2017-10-12 01:02:05
# 8    000106364568517340        dead_end 2017-10-12 01:03:43
# 9   0001348344294054462          direct 2017-06-05 15:06:24
# 10  0001348344294054462        dead_end 2017-06-05 15:06:25
# 11  0001737926054836229  organic_search 2017-10-15 07:35:02
# 12  0001737926054836229        dead_end 2017-10-15 07:36:21
# 13  0001858327036304483  organic_search 2017-01-10 18:29:50
# 14  0001858327036304483        dead_end 2017-01-10 18:29:59
#
#     conversion_proximity      sequence_id
# 0                  211.0  nW31ahtlgEpFWi1
# 1                    0.0  nW31ahtlgEpFWi1
# 2                    1.0  f6X79WOxA3jUxPU
# 3                    0.0  f6X79WOxA3jUxPU
# 4                 2193.0  L5wAoLtd1C6Cvvc
# 5                    1.0  L5wAoLtd1C6Cvvc
# 6                    0.0  L5wAoLtd1C6Cvvc
# 7                   98.0  maGY5aACPGJoF9o
# 8                    0.0  maGY5aACPGJoF9o
# 9                    1.0  VCl4OtCpaCafWUv
# 10                   0.0  VCl4OtCpaCafWUv
# 11                  79.0  Zk2OxiV5HEELkGm
# 12                   0.0  Zk2OxiV5HEELkGm
# 13                   9.0  iAFo5hAjvBWQleT
# 14                   0.0  iAFo5hAjvBWQleT

# %%
transactions_final_df = pd.concat([transactions_df,transactions_df2],ignore_index=True)
transactions_final_df = transactions_final_df[['sequence_id','fullVisitorId','event_name','event_datetime','conversion_proximity']]
transactions_final_df.sort_values(by=['sequence_id','conversion_proximity'],ascending=[True,False],inplace=True)

# %%
transactions_final_df.to_csv('../datasets/sequence_fact.csv',index=False)

# %%
visitor_detail_df.to_csv('../datasets/visitor_detail.csv', index=False)
